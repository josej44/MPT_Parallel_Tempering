# %%
using Revise
# Tensor_trains 
using TensorTrains, TensorCast, Tullio, LogarithmicNumbers, ProgressMeter, LinearAlgebra
using TensorTrains: compress!, TruncBondThresh  
using Printf

# MonteCarlo
using Random, Statistics, Distributions

# Graphics
using Plots, Colors

includet("../GlauberPT.jl/src/monte_carlo_efficient/observables.jl")
includet("../GlauberPT.jl/src/monte_carlo_efficient/parameters.jl")
includet("../GlauberPT.jl/src/monte_carlo_efficient/plots.jl")
includet("../GlauberPT.jl/src/monte_carlo_efficient/swap_criteria.jl")
includet("../GlauberPT.jl/src/monte_carlo_efficient/update_rules.jl")
includet("../GlauberPT.jl/src/monte_carlo_efficient/monte_carlo_general.jl")

includet("../GlauberPT.jl/src/tensor_train_efficient/auxiliary_tensor_train_tools.jl")
includet("../GlauberPT.jl/src/tensor_train_efficient/boltzmann_distribution_tt.jl")
includet("../GlauberPT.jl/src/tensor_train_efficient/efficient_observables.jl")
includet("../GlauberPT.jl/src/tensor_train_efficient/initialization_params.jl")
includet("../GlauberPT.jl/src/tensor_train_efficient/metropolis_swap_tt.jl")
includet("../GlauberPT.jl/src/tensor_train_efficient/tensor_train_evolution.jl")
includet("../GlauberPT.jl/src/tensor_train_efficient/transition_rates_builder.jl")

# %%
Revise.revise()

B = rand_tt(6, 20, 2, 2) 
B.z = exp(-100)
absorb_z_into_matrices!(B)
B = B + identity_tensor_train(B)
B_inv = inverse_tt(B, 7; steps=150)

X = [[(rand(1:2), rand(1:2)) for i in 1:length(B)] for _ in 1:1000]
error_sample = maximum(abs.([evaluate(B,x) for x in X] .- [1/evaluate(B_inv,x) for x in X]))
avg_error = mean(abs.([evaluate(B,x) for x in X] .- [1/evaluate(B_inv,x) for x in X]))
println(avg_error)
println(error_sample)
scatter([1/evaluate(B_inv,x) for x in X], [evaluate(B,x) for x in X])
# Out:
# B0 = +exp(-129.6176326025578)
# estimate_norm_tt(Bn) = +exp(-128.1989644634742)
# Bn.z = +exp(115.06160019959312)
# estimate_norm_tt(Bn) = +exp(-127.49942287708438)
# Bn.z = +exp(114.36853019997838)
# Progress:   1%|▌                                        |  ETA: 0:11:13
# estimate_norm_tt(Bn) = +exp(-126.79291170225733)
# Bn.z = +exp(113.6755373689111)
# estimate_norm_tt(Bn) = +exp(-126.05634838386055)
# Bn.z = +exp(112.98269883775646)
# estimate_norm_tt(Bn) = +exp(-125.25628305167642)
# Bn.z = +exp(112.29016875775069)
# estimate_norm_tt(Bn) = +exp(-124.3654182403634)
# Progress:   4%|█▋                                       |  ETA: 0:04:54
# Bn.z = +exp(111.59825498574992)
# estimate_norm_tt(Bn) = +exp(-123.36421532164724)
# Progress:   5%|█▉                                       |  ETA: 0:04:18
# Bn.z = +exp(110.90757145595275)
# estimate_norm_tt(Bn) = +exp(-122.25011485436644)
# Progress:   5%|██▏                                      |  ETA: 0:03:51
# Bn.z = +exp(110.21933894265587)
# estimate_norm_tt(Bn) = +exp(-121.04593225536597)
# Progress:   6%|██▌                                      |  ETA: 0:03:30
# Bn.z = +exp(109.53597081386634)
# estimate_norm_tt(Bn) = +exp(-119.80971573723896)
# Progress:   7%|██▊                                      |  ETA: 0:03:14
# Bn.z = +exp(108.86218271087631)
# estimate_norm_tt(Bn) = +exp(-118.35055699616986)
# Progress:   7%|███                                      |  ETA: 0:03:03
# Bn.z = +exp(108.20697528272063)
# estimate_norm_tt(Bn) = +exp(-116.94678353616838)
# Progress:   8%|███▎                                     |  ETA: 0:02:52
# Bn.z = +exp(107.58674007443778)
# estimate_norm_tt(Bn) = +exp(-115.74304766489819)
# Progress:   9%|███▌                                     |  ETA: 0:02:42
# Bn.z = +exp(107.02871727957644)
# estimate_norm_tt(Bn) = +exp(-114.96686015753704)
# Progress:   9%|███▉                                     |  ETA: 0:02:33
# Bn.z = +exp(106.57115639060272)
# estimate_norm_tt(Bn) = +exp(-114.05015749487951)
# Progress:  10%|████▏                                    |  ETA: 0:02:25
# Bn.z = +exp(106.2527504530312)
# estimate_norm_tt(Bn) = +exp(-112.72554596365508)
# Progress:  11%|████▍                                    |  ETA: 0:02:18
# Bn.z = +exp(106.08687600669683)
# estimate_norm_tt(Bn) = +exp(-112.01304354764483)
# Progress:  11%|████▋                                    |  ETA: 0:02:12
# Bn.z = +exp(106.03491662807441)
# estimate_norm_tt(Bn) = +exp(-113.29129707033006)
# Progress:  12%|████▉                                    |  ETA: 0:02:07
# Bn.z = +exp(106.02790622371836)
# estimate_norm_tt(Bn) = +exp(-114.00860845079588)
# Progress:  13%|█████▎                                   |  ETA: 0:02:02
# Bn.z = +exp(106.02759523113474)
# estimate_norm_tt(Bn) = +exp(-114.30847192357751)
# Progress:  13%|█████▌                                   |  ETA: 0:01:58
# Bn.z = +exp(106.02762346463348)
# estimate_norm_tt(Bn) = +exp(-114.3994462666127)
# Progress:  14%|█████▊                                   |  ETA: 0:01:53
# Bn.z = +exp(106.02759420861103)
# estimate_norm_tt(Bn) = +exp(-114.50566100966806)
# Progress:  15%|██████                                   |  ETA: 0:01:50
# Bn.z = +exp(106.0275926915059)
# estimate_norm_tt(Bn) = +exp(-114.49574112323145)
# Progress:  15%|██████▎                                  |  ETA: 0:01:46
# Bn.z = +exp(106.0275867926038)
# estimate_norm_tt(Bn) = +exp(-114.49550303857752)
# Progress:  16%|██████▌                                  |  ETA: 0:01:43
# Bn.z = +exp(106.02758595132569)
# estimate_norm_tt(Bn) = +exp(-114.49248991077555)
# Progress:  17%|██████▉                                  |  ETA: 0:01:41
# Bn.z = +exp(106.02758580595756)
# estimate_norm_tt(Bn) = +exp(-114.49615916167501)
# Progress:  17%|███████▏                                 |  ETA: 0:01:38
# Bn.z = +exp(106.02758548878536)
# estimate_norm_tt(Bn) = +exp(-114.49769906801949)
# Progress:  18%|███████▍                                 |  ETA: 0:01:36
# Bn.z = +exp(106.02758555897321)
# estimate_norm_tt(Bn) = +exp(-114.4983278289445)
# Progress:  19%|███████▋                                 |  ETA: 0:01:33
# Bn.z = +exp(106.02758543727437)
# estimate_norm_tt(Bn) = +exp(-114.49870251073446)
# Progress:  19%|███████▉                                 |  ETA: 0:01:31
# Bn.z = +exp(106.02758549321668)
# estimate_norm_tt(Bn) = +exp(-114.49809200273823)
# Progress:  20%|████████▎                                |  ETA: 0:01:29
# Bn.z = +exp(106.0275854975338)
# estimate_norm_tt(Bn) = +exp(-114.49889620420782)
# Progress:  21%|████████▌                                |  ETA: 0:01:27
# Bn.z = +exp(106.02758555803744)
# estimate_norm_tt(Bn) = +exp(-114.49770323811995)
# Progress:  21%|████████▊                                |  ETA: 0:01:25
# Bn.z = +exp(106.02758532935697)
# estimate_norm_tt(Bn) = +exp(-114.49930318208489)
# Progress:  22%|█████████                                |  ETA: 0:01:23
# Bn.z = +exp(106.0275857713779)
# estimate_norm_tt(Bn) = +exp(-114.49864186910526)
# Progress:  23%|█████████▎                               |  ETA: 0:01:21
# Bn.z = +exp(106.02758540101834)
# estimate_norm_tt(Bn) = +exp(-114.49903161587437)
# Progress:  23%|█████████▋                               |  ETA: 0:01:20
# Bn.z = +exp(106.02758582707321)
# estimate_norm_tt(Bn) = +exp(-114.49812705118458)
# Progress:  24%|█████████▉                               |  ETA: 0:01:18
# Bn.z = +exp(106.0275855900973)
# estimate_norm_tt(Bn) = +exp(-114.49904292531178)
# Progress:  25%|██████████▏                              |  ETA: 0:01:17
# Bn.z = +exp(106.02758564082025)
# estimate_norm_tt(Bn) = +exp(-114.49852721374533)
# Progress:  25%|██████████▍                              |  ETA: 0:01:16
# Bn.z = +exp(106.02758547256771)
# estimate_norm_tt(Bn) = +exp(-114.49879444467578)
# Progress:  26%|██████████▋                              |  ETA: 0:01:14
# Bn.z = +exp(106.02758565401724)
# estimate_norm_tt(Bn) = +exp(-114.49852797111119)
# Progress:  27%|██████████▉                              |  ETA: 0:01:13
# Bn.z = +exp(106.0275855343347)
# estimate_norm_tt(Bn) = +exp(-114.49923158568429)
# Progress:  27%|███████████▎                             |  ETA: 0:01:12
# Bn.z = +exp(106.0275855404481)
# estimate_norm_tt(Bn) = +exp(-114.49849031870068)
# Progress:  28%|███████████▌                             |  ETA: 0:01:11
# Bn.z = +exp(106.02758557017641)
# estimate_norm_tt(Bn) = +exp(-114.49944698363811)
# Progress:  29%|███████████▊                             |  ETA: 0:01:10
# Bn.z = +exp(106.02758558231454)
# estimate_norm_tt(Bn) = +exp(-114.49861635590223)
# Progress:  29%|████████████                             |  ETA: 0:01:09
# Bn.z = +exp(106.02758573326084)
# estimate_norm_tt(Bn) = +exp(-114.49963432150884)
# Progress:  30%|████████████▎                            |  ETA: 0:01:08
# Bn.z = +exp(106.0275856487132)
# estimate_norm_tt(Bn) = +exp(-114.49843148410886)
# Progress:  31%|████████████▋                            |  ETA: 0:01:06
# Bn.z = +exp(106.02758556889957)
# estimate_norm_tt(Bn) = +exp(-114.4993449797561)
# Progress:  31%|████████████▉                            |  ETA: 0:01:05
# Bn.z = +exp(106.02758562777058)
# estimate_norm_tt(Bn) = +exp(-114.49836033273455)
# Progress:  32%|█████████████▏                           |  ETA: 0:01:04
# Bn.z = +exp(106.02758552497569)
# estimate_norm_tt(Bn) = +exp(-114.49906892638518)
# Progress:  33%|█████████████▍                           |  ETA: 0:01:03
# Bn.z = +exp(106.02758558065605)
# estimate_norm_tt(Bn) = +exp(-114.49830073642939)
# Progress:  33%|█████████████▋                           |  ETA: 0:01:02
# Bn.z = +exp(106.02758553627633)
# estimate_norm_tt(Bn) = +exp(-114.49915744816845)
# Progress:  34%|██████████████                           |  ETA: 0:01:01
# Bn.z = +exp(106.02758557834075)
# estimate_norm_tt(Bn) = +exp(-114.49848499977931)
# Progress:  35%|██████████████▎                          |  ETA: 0:01:00
# Bn.z = +exp(106.0275855369465)
# estimate_norm_tt(Bn) = +exp(-114.49906945897698)
# Progress:  35%|██████████████▌                          |  ETA: 0:00:59
# Bn.z = +exp(106.0275856036292)
# estimate_norm_tt(Bn) = +exp(-114.49844661845707)
# Progress:  36%|██████████████▊                          |  ETA: 0:00:58
# Bn.z = +exp(106.02758552306966)
# estimate_norm_tt(Bn) = +exp(-114.49923000454012)
# Progress:  37%|███████████████                          |  ETA: 0:00:57
# Bn.z = +exp(106.0275854998614)
# estimate_norm_tt(Bn) = +exp(-114.49865842470345)
# Progress:  37%|███████████████▎                         |  ETA: 0:00:56
# Bn.z = +exp(106.0275856356455)
# estimate_norm_tt(Bn) = +exp(-114.49962190886893)
# Progress:  38%|███████████████▋                         |  ETA: 0:00:55
# Bn.z = +exp(106.02758537873353)
# estimate_norm_tt(Bn) = +exp(-114.49772544820247)
# Progress:  39%|███████████████▉                         |  ETA: 0:00:54
# Bn.z = +exp(106.02758554923395)
# estimate_norm_tt(Bn) = +exp(-114.49939837450286)
# Progress:  39%|████████████████▏                        |  ETA: 0:00:55
# Bn.z = +exp(106.02758549109741)
# estimate_norm_tt(Bn) = +exp(-114.49845186916302)
# Progress:  40%|████████████████▍                        |  ETA: 0:00:54
# Bn.z = +exp(106.0275855174729)
# estimate_norm_tt(Bn) = +exp(-114.49928550899656)
# Progress:  41%|████████████████▋                        |  ETA: 0:00:53
# Bn.z = +exp(106.0275854515967)
# estimate_norm_tt(Bn) = +exp(-114.49805081747687)
# Progress:  41%|█████████████████                        |  ETA: 0:00:53
# Bn.z = +exp(106.02758542360597)
# estimate_norm_tt(Bn) = +exp(-114.49929303129804)
# Progress:  42%|█████████████████▎                       |  ETA: 0:00:52
# Bn.z = +exp(106.02758564154374)
# estimate_norm_tt(Bn) = +exp(-114.49896107529085)
# Progress:  43%|█████████████████▌                       |  ETA: 0:00:51
# Bn.z = +exp(106.02758554527269)
# estimate_norm_tt(Bn) = +exp(-114.49963983911101)
# Progress:  43%|█████████████████▊                       |  ETA: 0:00:50
# Bn.z = +exp(106.0275855772077)
# estimate_norm_tt(Bn) = +exp(-114.49938627249624)
# Progress:  44%|██████████████████                       |  ETA: 0:00:49
# Bn.z = +exp(106.02758542551814)
# estimate_norm_tt(Bn) = +exp(-114.49966662714598)
# Progress:  45%|██████████████████▍                      |  ETA: 0:00:48
# Bn.z = +exp(106.02758547932875)
# estimate_norm_tt(Bn) = +exp(-114.49962720864457)
# Progress:  45%|██████████████████▋                      |  ETA: 0:00:48
# Bn.z = +exp(106.0275855032)
# estimate_norm_tt(Bn) = +exp(-114.49943698259536)
# Progress:  46%|██████████████████▉                      |  ETA: 0:00:47
# Bn.z = +exp(106.02758537868112)
# estimate_norm_tt(Bn) = +exp(-114.49964040945292)
# Progress:  47%|███████████████████▏                     |  ETA: 0:00:46
# Bn.z = +exp(106.02758541914972)
# estimate_norm_tt(Bn) = +exp(-114.49965568531967)
# Progress:  47%|███████████████████▍                     |  ETA: 0:00:45
# Bn.z = +exp(106.02758518780061)
# estimate_norm_tt(Bn) = +exp(-114.49992697409283)
# Progress:  48%|███████████████████▋                     |  ETA: 0:00:45
# Bn.z = +exp(106.02758552058523)
# estimate_norm_tt(Bn) = +exp(-114.49998905432324)
# Progress:  49%|████████████████████                     |  ETA: 0:00:44
# Bn.z = +exp(106.02758523219545)
# estimate_norm_tt(Bn) = +exp(-114.49958206730945)
# Progress:  49%|████████████████████▎                    |  ETA: 0:00:43
# Bn.z = +exp(106.0275854600396)
# estimate_norm_tt(Bn) = +exp(-114.49984404109121)
# Progress:  50%|████████████████████▌                    |  ETA: 0:00:42
# Bn.z = +exp(106.02758514735004)
# estimate_norm_tt(Bn) = +exp(-114.49968806627345)
# Progress:  51%|████████████████████▊                    |  ETA: 0:00:42
# Bn.z = +exp(106.02758534458043)
# estimate_norm_tt(Bn) = +exp(-114.49984699252074)
# Progress:  51%|█████████████████████                    |  ETA: 0:00:41
# Bn.z = +exp(106.0275851733577)
# estimate_norm_tt(Bn) = +exp(-114.50040334618123)
# Progress:  52%|█████████████████████▍                   |  ETA: 0:00:40
# Bn.z = +exp(106.02758534330991)
# estimate_norm_tt(Bn) = +exp(-114.49964053597063)
# Progress:  53%|█████████████████████▋                   |  ETA: 0:00:39
# Bn.z = +exp(106.02758509103805)
# estimate_norm_tt(Bn) = +exp(-114.49995735871687)
# Progress:  53%|█████████████████████▉                   |  ETA: 0:00:39
# Bn.z = +exp(106.02758545574883)
# estimate_norm_tt(Bn) = +exp(-114.50033316405651)
# Progress:  54%|██████████████████████▏                  |  ETA: 0:00:38
# Bn.z = +exp(106.02758515459757)
# estimate_norm_tt(Bn) = +exp(-114.49992885948225)
# Progress:  55%|██████████████████████▍                  |  ETA: 0:00:37
# Bn.z = +exp(106.02758542860998)
# estimate_norm_tt(Bn) = +exp(-114.50012031690956)
# Progress:  55%|██████████████████████▋                  |  ETA: 0:00:37
# Bn.z = +exp(106.02758510723051)
# estimate_norm_tt(Bn) = +exp(-114.49987478911717)
# Progress:  56%|███████████████████████                  |  ETA: 0:00:36
# Bn.z = +exp(106.02758537757887)
# estimate_norm_tt(Bn) = +exp(-114.50020152438054)
# Progress:  57%|███████████████████████▎                 |  ETA: 0:00:35
# Bn.z = +exp(106.02758508571515)
# estimate_norm_tt(Bn) = +exp(-114.49985457969557)
# Progress:  57%|███████████████████████▌                 |  ETA: 0:00:35
# Bn.z = +exp(106.02758533591533)
# estimate_norm_tt(Bn) = +exp(-114.50047859972962)
# Progress:  58%|███████████████████████▊                 |  ETA: 0:00:34
# Bn.z = +exp(106.02758520396891)
# estimate_norm_tt(Bn) = +exp(-114.50020785325296)
# Progress:  59%|████████████████████████                 |  ETA: 0:00:33
# Bn.z = +exp(106.02758537416055)
# estimate_norm_tt(Bn) = +exp(-114.50056076023918)
# Progress:  59%|████████████████████████▍                |  ETA: 0:00:33
# Bn.z = +exp(106.02758504934535)
# estimate_norm_tt(Bn) = +exp(-114.50046280573012)
# Progress:  60%|████████████████████████▋                |  ETA: 0:00:32
# Bn.z = +exp(106.02758524638816)
# estimate_norm_tt(Bn) = +exp(-114.50062610375855)
# Progress:  61%|████████████████████████▉                |  ETA: 0:00:32
# Bn.z = +exp(106.02758511379655)
# estimate_norm_tt(Bn) = +exp(-114.50061113881355)
# Progress:  61%|█████████████████████████▏               |  ETA: 0:00:31
# Bn.z = +exp(106.02758535964509)
# estimate_norm_tt(Bn) = +exp(-114.50060816034544)
# Progress:  62%|█████████████████████████▍               |  ETA: 0:00:30
# Bn.z = +exp(106.02758500159626)
# estimate_norm_tt(Bn) = +exp(-114.50159920834112)
# Progress:  63%|█████████████████████████▊               |  ETA: 0:00:30
# Bn.z = +exp(106.02758536673898)
# estimate_norm_tt(Bn) = +exp(-114.50032645757885)
# Progress:  63%|██████████████████████████               |  ETA: 0:00:29
# Bn.z = +exp(106.02758497388989)
# estimate_norm_tt(Bn) = +exp(-114.50091579070227)
# Progress:  64%|██████████████████████████▎              |  ETA: 0:00:29
# Bn.z = +exp(106.02758531168082)
# estimate_norm_tt(Bn) = +exp(-114.50044783773461)
# Progress:  65%|██████████████████████████▌              |  ETA: 0:00:28
# Bn.z = +exp(106.02758512864696)
# estimate_norm_tt(Bn) = +exp(-114.50132670617882)
# Progress:  65%|██████████████████████████▊              |  ETA: 0:00:27
# Bn.z = +exp(106.02758520687455)
# estimate_norm_tt(Bn) = +exp(-114.50021382615301)
# Progress:  66%|███████████████████████████              |  ETA: 0:00:27
# Bn.z = +exp(106.02758508570417)
# estimate_norm_tt(Bn) = +exp(-114.50102433838839)
# Progress:  67%|███████████████████████████▍             |  ETA: 0:00:26
# Bn.z = +exp(106.02758512559718)
# estimate_norm_tt(Bn) = +exp(-114.5003580654679)
# Progress:  67%|███████████████████████████▋             |  ETA: 0:00:26
# Bn.z = +exp(106.02758521983007)
# estimate_norm_tt(Bn) = +exp(-114.50098863486707)
# Progress:  68%|███████████████████████████▉             |  ETA: 0:00:25
# Bn.z = +exp(106.02758515229768)
# estimate_norm_tt(Bn) = +exp(-114.50005802876113)
# Progress:  69%|████████████████████████████▏            |  ETA: 0:00:25
# Bn.z = +exp(106.02758518153237)
# estimate_norm_tt(Bn) = +exp(-114.50062226721938)
# Progress:  69%|████████████████████████████▍            |  ETA: 0:00:24
# Bn.z = +exp(106.02758511637306)
# estimate_norm_tt(Bn) = +exp(-114.5002050775556)
# Progress:  70%|████████████████████████████▊            |  ETA: 0:00:24
# Bn.z = +exp(106.027585181854)
# estimate_norm_tt(Bn) = +exp(-114.50071099131586)
# Progress:  71%|█████████████████████████████            |  ETA: 0:00:23
# Bn.z = +exp(106.02758531074329)
# estimate_norm_tt(Bn) = +exp(-114.50077589590815)
# Progress:  71%|█████████████████████████████▎           |  ETA: 0:00:23
# Bn.z = +exp(106.02758512202789)
# estimate_norm_tt(Bn) = +exp(-114.50108584956936)
# Progress:  72%|█████████████████████████████▌           |  ETA: 0:00:22
# Bn.z = +exp(106.02758505533716)
# estimate_norm_tt(Bn) = +exp(-114.50064791631289)
# Progress:  73%|█████████████████████████████▊           |  ETA: 0:00:21
# Bn.z = +exp(106.02758511439951)
# estimate_norm_tt(Bn) = +exp(-114.50151861254592)
# Progress:  73%|██████████████████████████████▏          |  ETA: 0:00:21
# Bn.z = +exp(106.0275852954095)
# estimate_norm_tt(Bn) = +exp(-114.50095096048851)
# Progress:  74%|██████████████████████████████▍          |  ETA: 0:00:20
# Bn.z = +exp(106.0275851233424)
# estimate_norm_tt(Bn) = +exp(-114.50152465776819)
# Progress:  75%|██████████████████████████████▋          |  ETA: 0:00:20
# Bn.z = +exp(106.02758505326189)
# estimate_norm_tt(Bn) = +exp(-114.50061264799075)
# Progress:  75%|██████████████████████████████▉          |  ETA: 0:00:19
# Bn.z = +exp(106.02758509221718)
# estimate_norm_tt(Bn) = +exp(-114.50144518140742)
# Progress:  76%|███████████████████████████████▏         |  ETA: 0:00:19
# Bn.z = +exp(106.02758523162845)
# estimate_norm_tt(Bn) = +exp(-114.50059918026865)
# Progress:  77%|███████████████████████████████▍         |  ETA: 0:00:18
# Bn.z = +exp(106.02758519282999)
# estimate_norm_tt(Bn) = +exp(-114.50144060859016)
# Progress:  77%|███████████████████████████████▊         |  ETA: 0:00:18
# Bn.z = +exp(106.02758511198134)
# estimate_norm_tt(Bn) = +exp(-114.500888941717)
# Progress:  78%|████████████████████████████████         |  ETA: 0:00:17
# Bn.z = +exp(106.02758523239815)
# estimate_norm_tt(Bn) = +exp(-114.50119514223236)
# Progress:  79%|████████████████████████████████▎        |  ETA: 0:00:17
# Bn.z = +exp(106.02758525258326)
# estimate_norm_tt(Bn) = +exp(-114.5013891550234)
# Progress:  79%|████████████████████████████████▌        |  ETA: 0:00:16
# Bn.z = +exp(106.02758506398658)
# estimate_norm_tt(Bn) = +exp(-114.50130981039585)
# Progress:  80%|████████████████████████████████▊        |  ETA: 0:00:15
# Bn.z = +exp(106.02758509834872)
# estimate_norm_tt(Bn) = +exp(-114.50115705237563)
# Progress:  81%|█████████████████████████████████▏       |  ETA: 0:00:15
# Bn.z = +exp(106.02758518396357)
# estimate_norm_tt(Bn) = +exp(-114.50156145723444)
# Progress:  81%|█████████████████████████████████▍       |  ETA: 0:00:14
# Bn.z = +exp(106.02758532251679)
# estimate_norm_tt(Bn) = +exp(-114.50127289752812)
# Progress:  82%|█████████████████████████████████▋       |  ETA: 0:00:14
# Bn.z = +exp(106.02758503141885)
# estimate_norm_tt(Bn) = +exp(-114.50136697277688)
# Progress:  83%|█████████████████████████████████▉       |  ETA: 0:00:13
# Bn.z = +exp(106.02758524225544)
# estimate_norm_tt(Bn) = +exp(-114.50105856392445)
# Progress:  83%|██████████████████████████████████▏      |  ETA: 0:00:13
# Bn.z = +exp(106.02758512621732)
# estimate_norm_tt(Bn) = +exp(-114.50111221281375)
# Progress:  84%|██████████████████████████████████▌      |  ETA: 0:00:12
# Bn.z = +exp(106.02758519700205)
# estimate_norm_tt(Bn) = +exp(-114.50111896899872)
# Progress:  85%|██████████████████████████████████▊      |  ETA: 0:00:12
# Bn.z = +exp(106.02758523176038)
# estimate_norm_tt(Bn) = +exp(-114.50150694758342)
# Progress:  85%|███████████████████████████████████      |  ETA: 0:00:11
# Bn.z = +exp(106.02758529950596)
# estimate_norm_tt(Bn) = +exp(-114.50103698802884)
# Progress:  86%|███████████████████████████████████▎     |  ETA: 0:00:11
# Bn.z = +exp(106.0275849864974)
# estimate_norm_tt(Bn) = +exp(-114.50119326399495)
# Progress:  87%|███████████████████████████████████▌     |  ETA: 0:00:10
# Bn.z = +exp(106.0275851964712)
# estimate_norm_tt(Bn) = +exp(-114.50117324505489)
# Progress:  87%|███████████████████████████████████▊     |  ETA: 0:00:10
# Bn.z = +exp(106.02758515220049)
# estimate_norm_tt(Bn) = +exp(-114.50128161030189)
# Progress:  88%|████████████████████████████████████▏    |  ETA: 0:00:09
# Bn.z = +exp(106.02758514046297)
# estimate_norm_tt(Bn) = +exp(-114.50105662024956)
# Progress:  89%|████████████████████████████████████▍    |  ETA: 0:00:09
# Bn.z = +exp(106.02758504683108)
# estimate_norm_tt(Bn) = +exp(-114.50143145057912)
# Progress:  89%|████████████████████████████████████▋    |  ETA: 0:00:08
# Bn.z = +exp(106.02758505581512)
# estimate_norm_tt(Bn) = +exp(-114.50129993325018)
# Progress:  90%|████████████████████████████████████▉    |  ETA: 0:00:08
# Bn.z = +exp(106.02758509659404)
# estimate_norm_tt(Bn) = +exp(-114.50120164698059)
# Progress:  91%|█████████████████████████████████████▏   |  ETA: 0:00:07
# Bn.z = +exp(106.02758508210069)
# estimate_norm_tt(Bn) = +exp(-114.50123776693377)
# Progress:  91%|█████████████████████████████████████▌   |  ETA: 0:00:07
# Bn.z = +exp(106.02758522493356)
# estimate_norm_tt(Bn) = +exp(-114.50127930214848)
# Progress:  92%|█████████████████████████████████████▊   |  ETA: 0:00:06
# Bn.z = +exp(106.02758513864791)
# estimate_norm_tt(Bn) = +exp(-114.50134960852628)
# Progress:  93%|██████████████████████████████████████   |  ETA: 0:00:06
# Bn.z = +exp(106.02758516914909)
# estimate_norm_tt(Bn) = +exp(-114.50133874535635)
# Progress:  93%|██████████████████████████████████████▎  |  ETA: 0:00:05
# Bn.z = +exp(106.02758515628804)
# estimate_norm_tt(Bn) = +exp(-114.50151761747469)
# Progress:  94%|██████████████████████████████████████▌  |  ETA: 0:00:04
# Bn.z = +exp(106.02758504945702)
# estimate_norm_tt(Bn) = +exp(-114.50139660535045)
# Progress:  95%|██████████████████████████████████████▉  |  ETA: 0:00:04
# Bn.z = +exp(106.0275851477143)
# estimate_norm_tt(Bn) = +exp(-114.50130488299368)
# Progress:  95%|███████████████████████████████████████▏ |  ETA: 0:00:03
# Bn.z = +exp(106.02758519972545)
# estimate_norm_tt(Bn) = +exp(-114.5013145712481)
# Progress:  96%|███████████████████████████████████████▍ |  ETA: 0:00:03
# Bn.z = +exp(106.02758523075555)
# estimate_norm_tt(Bn) = +exp(-114.50148755490814)
# Progress:  97%|███████████████████████████████████████▋ |  ETA: 0:00:02
# Bn.z = +exp(106.02758495110955)
# estimate_norm_tt(Bn) = +exp(-114.50148626462075)
# Progress:  97%|███████████████████████████████████████▉ |  ETA: 0:00:02
# Bn.z = +exp(106.02758522456696)
# estimate_norm_tt(Bn) = +exp(-114.50146122828224)
# Progress:  98%|████████████████████████████████████████▏|  ETA: 0:00:01
# Bn.z = +exp(106.02758503517575)
# estimate_norm_tt(Bn) = +exp(-114.50174635235665)
# Progress:  99%|████████████████████████████████████████▌|  ETA: 0:00:01
# Bn.z = +exp(106.02758521335426)
# estimate_norm_tt(Bn) = +exp(-114.50170679529516)
# Progress:  99%|████████████████████████████████████████▊|  ETA: 0:00:00
# Bn.z = +exp(106.02758501959138)
# estimate_norm_tt(Bn) = +exp(-114.50171284654176)
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:14
# Bn.z = +exp(106.02758522699119)
# 1.4357596185167098e48
# 1.0745559804784205e49

# %%
Revise.revise()

B = rand_tt(4, 40, 4) 
# B.z = exp(-100)
absorb_z_into_matrices!(B)
B = B + identity_tensor_train(B)
B_inv, z_acc = inverse_tt_improve(B, 10; steps=50)

X = [[rand(1:4) for i in 1:length(B)] for _ in 1:100]
# error_sample = maximum(abs.([evaluate(B,x) for x in X] .- [1/evaluate(B_inv,x) for x in X]))
# avg_error = mean(abs.([evaluate(B,x) for x in X] .- [1/evaluate(B_inv,x) for x in X]))
# println(avg_error)ticks
# println(error_sample)
# scatter([1/evaluate(B_inv,x) for x in X], [evaluate(B,x) for x in X])
display([evaluate(B_inv,x) for x in X])
# Out:
# B0 = +exp(-45.23889139422941)
# estimate_norm_tt(Bn) = +exp(-12.876942501778924)
# Bn.z = +exp(28.347319855064484)
# estimate_norm_tt(Bn) =
# Progress:   4%|█▋                                       |  ETA: 0:01:40
# +exp(-13.08917619305806)
# Bn.z = +exp(28.31709853417796)
# estimate_norm_tt(Bn) = +exp(-13.089176193043993)
# Progress:   6%|██▌                                      |  ETA: 0:01:59
# Bn.z = +exp(28.317098534177855)
# estimate_norm_tt(Bn) = +exp(-13.089176193020009)
# Progress:   8%|███▎                                     |  ETA: 0:02:24
# Bn.z = +exp(28.317098534177656)
# estimate_norm_tt(Bn) = +exp(-13.089176192986276)
# Progress:  10%|████▏                                    |  ETA: 0:02:22
# Bn.z = +exp(28.31709853417744)
# estimate_norm_tt(Bn) = +exp(-13.089176192940416)
# Progress:  12%|████▉                                    |  ETA: 0:02:21
# Bn.z = +exp(28.317098534177145)
# estimate_norm_tt(Bn) = +exp(-13.089176192872657)
# Progress:  14%|█████▊                                   |  ETA: 0:02:19
# Bn.z = +exp(28.317098534176697)
# estimate_norm_tt(Bn) = +exp(-13.089176192701263)
# Progress:  16%|██████▌                                  |  ETA: 0:02:25
# Bn.z = +exp(28.317098534175663)
# estimate_norm_tt(Bn) = +exp(-13.089176192766045)
# Progress:  18%|███████▍                                 |  ETA: 0:02:20
# Bn.z = +exp(28.317098534176047)
# estimate_norm_tt(Bn) = +exp(-13.089176192912378)
# Progress:  20%|████████▎                                |  ETA: 0:02:18
# Bn.z = +exp(28.317098534176903)
# estimate_norm_tt(Bn) = +exp(-13.089176192827743)
# Progress:  22%|█████████                                |  ETA: 0:02:14
# Bn.z = +exp(28.317098534176377)
# estimate_norm_tt(Bn) = +exp(-13.08917619147354)
# Progress:  24%|█████████▉                               |  ETA: 0:02:10
# Bn.z = +exp(28.31709853416807)
# estimate_norm_tt(Bn) = +exp(-13.089176191489539)
# Progress:  26%|██████████▋                              |  ETA: 0:02:09
# Bn.z = +exp(28.31709853416821)
# estimate_norm_tt(Bn) = +exp(-13.089176191515186)
# Progress:  28%|███████████▌                             |  ETA: 0:02:05
# Bn.z = +exp(28.317098534168352)
# estimate_norm_tt(Bn) = +exp(-13.089176191550834)
# Progress:  30%|████████████▎                            |  ETA: 0:02:01
# Bn.z = +exp(28.317098534168558)
# estimate_norm_tt(Bn) = +exp(-13.08917619159962)
# Progress:  32%|█████████████▏                           |  ETA: 0:01:57
# Bn.z = +exp(28.317098534168828)
# estimate_norm_tt(Bn) = +exp(-13.089176191674534)
# Progress:  34%|██████████████                           |  ETA: 0:01:53
# Bn.z = +exp(28.317098534169258)
# estimate_norm_tt(Bn) = +exp(-13.089176191958689)
# Progress:  36%|██████████████▊                          |  ETA: 0:01:48
# Bn.z = +exp(28.317098534170952)
# estimate_norm_tt(Bn) = +exp(-13.089176191921599)
# Progress:  38%|███████████████▋                         |  ETA: 0:01:47
# Bn.z = +exp(28.317098534170682)
# estimate_norm_tt(Bn) = +exp(-13.089176191870678)
# Progress:  40%|████████████████▍                        |  ETA: 0:01:44
# Bn.z = +exp(28.31709853417037)
# estimate_norm_tt(Bn) = +exp(-13.089176191789788)
# Progress:  42%|█████████████████▎                       |  ETA: 0:01:40
# Bn.z = +exp(28.31709853416984)
# estimate_norm_tt(Bn) = +exp(-13.089176191227098)
# Progress:  44%|██████████████████                       |  ETA: 0:01:36
# Bn.z = +exp(28.317098534166387)
# estimate_norm_tt(Bn) = +exp(-13.089176191250573)
# Progress:  46%|██████████████████▉                      |  ETA: 0:01:32
# Bn.z = +exp(28.317098534166547)
# estimate_norm_tt(Bn) = +exp(-13.089176191283833)
# Progress:  48%|███████████████████▋                     |  ETA: 0:01:28
# Bn.z = +exp(28.317098534166735)
# estimate_norm_tt(Bn) = +exp(-13.08917619132898)
# Progress:  50%|████████████████████▌                    |  ETA: 0:01:24
# Bn.z = +exp(28.317098534166963)
# estimate_norm_tt(Bn) = +exp(-13.08917619139516)
# Progress:  52%|█████████████████████▍                   |  ETA: 0:01:21
# Bn.z = +exp(28.317098534167364)
# estimate_norm_tt(Bn) = +exp(-13.08917619155273)
# Progress:  54%|██████████████████████▏                  |  ETA: 0:01:17
# Bn.z = +exp(28.317098534168288)
# estimate_norm_tt(Bn) = +exp(-13.08917619147864)
# Progress:  56%|███████████████████████                  |  ETA: 0:01:13
# Bn.z = +exp(28.317098534167815)
# estimate_norm_tt(Bn) = +exp(-13.089176191214786)
# Progress:  58%|███████████████████████▊                 |  ETA: 0:01:10
# Bn.z = +exp(28.317098534166178)
# estimate_norm_tt(Bn) = +exp(-13.089176191254257)
# Progress:  60%|████████████████████████▋                |  ETA: 0:01:06
# Bn.z = +exp(28.3170985341664)
# estimate_norm_tt(Bn) = +exp(-13.089176191309315)
# Progress:  62%|█████████████████████████▍               |  ETA: 0:01:03
# Bn.z = +exp(28.317098534166707)
# estimate_norm_tt(Bn) = +exp(-13.089176191404015)
# Progress:  64%|██████████████████████████▎              |  ETA: 0:00:59
# Bn.z = +exp(28.317098534167275)
# estimate_norm_tt(Bn) = +exp(-13.089176190861961)
# Progress:  66%|███████████████████████████              |  ETA: 0:00:57
# Bn.z = +exp(28.317098534163954)
# estimate_norm_tt(Bn) = +exp(-13.08917619088594)
# Progress:  68%|███████████████████████████▉             |  ETA: 0:00:54
# Bn.z = +exp(28.31709853416408)
# estimate_norm_tt(Bn) = +exp(-13.089176190919698)
# Progress:  70%|████████████████████████████▊            |  ETA: 0:00:50
# Bn.z = +exp(28.317098534164284)
# estimate_norm_tt(Bn) = +exp(-13.089176190965574)
# Progress:  72%|█████████████████████████████▌           |  ETA: 0:00:47
# Bn.z = +exp(28.31709853416453)
# estimate_norm_tt(Bn) = +exp(-13.089176191033486)
# Progress:  74%|██████████████████████████████▍          |  ETA: 0:00:43
# Bn.z = +exp(28.317098534164924)
# estimate_norm_tt(Bn) = +exp(-13.0891761912066)
# Progress:  76%|███████████████████████████████▏         |  ETA: 0:00:40
# Bn.z = +exp(28.31709853416595)
# estimate_norm_tt(Bn) = +exp(-13.089176191142696)
# Progress:  78%|████████████████████████████████         |  ETA: 0:00:37
# Bn.z = +exp(28.317098534165527)
# estimate_norm_tt(Bn) = +exp(-13.089176191003283)
# Progress:  80%|████████████████████████████████▊        |  ETA: 0:00:33
# Bn.z = +exp(28.31709853416465)
# estimate_norm_tt(Bn) = +exp(-13.08917619109676)
# Progress:  82%|█████████████████████████████████▋       |  ETA: 0:00:30
# Bn.z = +exp(28.31709853416521)
# estimate_norm_tt(Bn) = +exp(-13.089176190455735)
# Progress:  84%|██████████████████████████████████▌      |  ETA: 0:00:27
# Bn.z = +exp(28.317098534161254)
# estimate_norm_tt(Bn) = +exp(-13.089176190477668)
# Progress:  86%|███████████████████████████████████▎     |  ETA: 0:00:23
# Bn.z = +exp(28.317098534161413)
# estimate_norm_tt(Bn) = +exp(-13.089176190509239)
# Progress:  88%|████████████████████████████████████▏    |  ETA: 0:00:20
# Bn.z = +exp(28.31709853416158)
# estimate_norm_tt(Bn) = +exp(-13.089176190552163)
# Progress:  90%|████████████████████████████████████▉    |  ETA: 0:00:17
# Bn.z = +exp(28.31709853416182)
# estimate_norm_tt(Bn) = +exp(-13.089176190613632)
# Progress:  92%|█████████████████████████████████████▊   |  ETA: 0:00:13
# Bn.z = +exp(28.317098534162167)
# estimate_norm_tt(Bn) = +exp(-13.089176190738083)
# Progress:  94%|██████████████████████████████████████▌  |  ETA: 0:00:10
# Bn.z = +exp(28.317098534162913)
# estimate_norm_tt(Bn) = +exp(-13.089176190614577)
# Progress:  96%|███████████████████████████████████████▍ |  ETA: 0:00:07
# Bn.z = +exp(28.317098534162113)
# estimate_norm_tt(Bn) = +exp(-13.089176190740922)
# Progress:  98%|████████████████████████████████████████▏|  ETA: 0:00:03
# Bn.z = +exp(28.31709853416289)
# estimate_norm_tt(Bn) = +exp(-13.08917619062249)
# Progress: 100%|█████████████████████████████████████████| Time: 0:02:49
# 100-element Vector{Float64}:
#   1.029512351822439e-24
#   1.0577286936985146e-24
#   3.0453998028453995e-25
#   9.383243004837549e-25
#   1.004330373922676e-24
#   9.614700496599578e-25
#   9.088036030100446e-25
#   8.526367009001781e-25
#   1.1418706517699927e-24
#   4.671015884417724e-25
#   ⋮
#   9.447622399180756e-25
#  -1.2819756880923061e-25
#   1.0891205279250309e-24
#   1.0457314315488149e-24
#   9.279876647952072e-25
#   1.1821321625149644e-24
#   8.841168820681175e-25
#   7.231173378838585e-25
#   1.0057329645795994e-24
# Bn.z = +exp(28.317098534162128)

# %%
B_inv.z *= z_acc
# Out:
# +exp(485.32405591938647)

# %%
normalize!(B)
x = rand([1,2], 40)
evaluate(B,x)
# Out:
# 9.423693172338814e-25

# %%
Revise.revise()

B = rand_tt(5, 50, 4) 
B.z = exp(-200)
absorb_z_into_matrices!(B)
B = B + identity_tensor_train(B)
B_inv = inverse_tt(B, 5; steps=20)

X = [[rand(1:4) for i in 1:length(B)] for _ in 1:1000]
error_sample = maximum(abs.([evaluate(B,x) for x in X] .- [1/evaluate(B_inv,x) for x in X]))
avg_error = mean(abs.([evaluate(B,x) for x in X] .- [1/evaluate(B_inv,x) for x in X]))
println(avg_error)
println(error_sample)
scatter([1/evaluate(B_inv,x) for x in X], [evaluate(B,x) for x in X])
# Out:
# B0 = +exp(-267.7285327007462)
# estimate_norm_tt(Bn) = +exp(-233.94229211884536)
# Bn.z = +exp(242.35703245874484)
# estimate_norm_tt(Bn) =
# Progress:  10%|████▏                                    |  ETA: 0:00:08
# +exp(-233.17842040879276)
# Bn.z = +exp(241.55255062119193)
# estimate_norm_tt(Bn) = +exp(-232.46499074346636)
# Progress:  15%|██████▏                                  |  ETA: 0:00:07
# Bn.z = +exp(240.83836762584698)
# estimate_norm_tt(Bn) = +exp(-231.63134445166912)
# Progress:  20%|████████▎                                |  ETA: 0:00:06
# Bn.z = +exp(240.0327868342568)
# estimate_norm_tt(Bn) = +exp(-226.86183425983015)
# Progress:  25%|██████████▎                              |  ETA: 0:00:05
# Bn.z = +exp(234.04743009690208)
# estimate_norm_tt(Bn) = +exp(-215.55694297219657)
# Progress:  30%|████████████▎                            |  ETA: 0:00:05
# Bn.z = +exp(218.38002282804212)
# estimate_norm_tt(Bn) = +exp(-187.45234667766672)
# Progress:  35%|██████████████▍                          |  ETA: 0:00:05
# Bn.z = +exp(187.87976198197128)
# estimate_norm_tt(Bn) = +exp(-127.40228184290683)
# Progress:  40%|████████████████▍                        |  ETA: 0:00:04
# Bn.z = +exp(127.38878678510542)
# estimate_norm_tt(Bn) = +exp(-5.61403730227572)
# Progress:  45%|██████████████████▌                      |  ETA: 0:00:04
# Bn.z = +exp(5.230588759934489)
# estimate_norm_tt(Bn) = +exp(238.21130994385186)
# Progress:  50%|████████████████████▌                    |  ETA: 0:00:04
# Bn.z = +exp(-238.34601835110604)
# estimate_norm_tt(Bn) = +exp(725.8736279832275)
# Progress:  55%|██████████████████████▌                  |  ETA: 0:00:03
# Bn.z = +exp(-725.9096863322385)
# ArgumentError: invalid argument #4 to LAPACK call
#
#
#
# Stacktrace:
#
#   [1] chklapackerror
#
#     @ /snap/julia/157/share/julia/stdlib/v1.12/LinearAlgebra/src/lapack.jl:38 [inlined]
#
#   [2] gesdd!(job::Char, A::Matrix{Float64})
#
#     @ LinearAlgebra.LAPACK /snap/julia/157/share/julia/stdlib/v1.12/LinearAlgebra/src/lapack.jl:1714
#
#   [3] _svd!
#
#     @ /snap/julia/157/share/julia/stdlib/v1.12/LinearAlgebra/src/svd.jl:125 [inlined]
#
#   [4] svd!(A::Matrix{Float64}; full::Bool, alg::LinearAlgebra.DivideAndConquer)
#
#     @ LinearAlgebra /snap/julia/157/share/julia/stdlib/v1.12/LinearAlgebra/src/svd.jl:105
#
#   [5] svd!
#
#     @ /snap/julia/157/share/julia/stdlib/v1.12/LinearAlgebra/src/svd.jl:100 [inlined]
#
#   [6] svd(A::Matrix{Float64}; full::Bool, alg::LinearAlgebra.DivideAndConquer)
#
#     @ LinearAlgebra /snap/julia/157/share/julia/stdlib/v1.12/LinearAlgebra/src/svd.jl:180
#
#   [7] svd
#
#     @ /snap/julia/157/share/julia/stdlib/v1.12/LinearAlgebra/src/svd.jl:179 [inlined]
#
#   [8] (::TruncThresh{Float64})(M::Matrix{Float64})
#
#     @ TensorTrains /media/julian/Nuevo vol/UNIVERSIDAD/Investigación_Mulet/Parallel_Tempering_Italia/Codigos/MPT_Parallel_Tempering/TensorTrains.jl/src/svd_trunc.jl:37
#
#   [9] orthogonalize_right!(C::TensorTrain{Float64, 3, Array{Float64, 3}, LogFloat64}; svd_trunc::TruncThresh{Float64}, indices::UnitRange{Int64})
#
#     @ TensorTrains /media/julian/Nuevo vol/UNIVERSIDAD/Investigación_Mulet/Parallel_Tempering_Italia/Codigos/MPT_Parallel_Tempering/TensorTrains.jl/src/tensor_train.jl:164
#
#  [10] orthogonalize_right!
#
#     @ /media/julian/Nuevo vol/UNIVERSIDAD/Investigación_Mulet/Parallel_Tempering_Italia/Codigos/MPT_Parallel_Tempering/TensorTrains.jl/src/tensor_train.jl:151 [inlined]
#
#  [11] compress!(A::TensorTrain{Float64, 3, Array{Float64, 3}, LogFloat64}; svd_trunc::TruncBond, is_orthogonal::Symbol)
#
#     @ TensorTrains /media/julian/Nuevo vol/UNIVERSIDAD/Investigación_Mulet/Parallel_Tempering_Italia/Codigos/MPT_Parallel_Tempering/TensorTrains.jl/src/abstract_tensor_train.jl:260
#
#  [12] macro expansion
#
#     @ /media/julian/Nuevo vol/UNIVERSIDAD/Investigación_Mulet/Parallel_Tempering_Italia/Codigos/MPT_Parallel_Tempering/GlauberPT.jl/src/tensor_train_efficient/auxiliary_tensor_train_tools.jl:139 [inlined]
#
#  [13] macro expansion
#
#     @ ~/.julia/packages/ProgressMeter/N660J/src/ProgressMeter.jl:1026 [inlined]
#
#  [14] inverse_tt(B::TensorTrain{Float64, 3, Array{Float64, 3}, LogFloat64}, bond::Int64; steps::Int64)
#
#     @ Main /media/julian/Nuevo vol/UNIVERSIDAD/Investigación_Mulet/Parallel_Tempering_Italia/Codigos/MPT_Parallel_Tempering/GlauberPT.jl/src/tensor_train_efficient/auxiliary_tensor_train_tools.jl:125
#
#  [15] top-level scope
#
#     @ /media/julian/Nuevo vol/UNIVERSIDAD/Investigación_Mulet/Parallel_Tempering_Italia/Codigos/MPT_Parallel_Tempering/GlauberPT_test/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:7
